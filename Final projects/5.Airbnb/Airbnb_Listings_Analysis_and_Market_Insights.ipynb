# %% [markdown]
# # **Project Name**    - Airbnb Listings Analysis and Market Insights

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project analyzes an Airbnb listings dataset to understand pricing patterns, host activity, room type distribution, property availability, and customer review trends. The dataset contains information such as listing prices, room types, neighborhoods, host details, availability throughout the year, minimum stay requirements, and customer reviews.
#
# The analysis focuses on cleaning missing values, exploring key business metrics, identifying popular neighborhoods, comparing room types, and understanding the factors that influence listing prices and booking availability. Various visualizations are created using Python libraries such as Pandas, Matplotlib, and Seaborn to generate meaningful insights that can help hosts optimize their listings and assist travelers in making informed accommodation decisions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Airbnb platform hosts thousands of properties across different neighborhoods, making it difficult for hosts to determine competitive pricing and for guests to identify the most suitable accommodation. Differences in room types, availability, review counts, minimum stay requirements, and neighborhood locations significantly impact booking decisions and revenue.
#
# The objective of this project is to analyze Airbnb listing data to identify pricing trends, customer preferences, neighborhood performance, and host activity. The insights generated from this analysis will support better pricing strategies, improve occupancy rates, and help both hosts and guests make data-driven decisions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to analyze Airbnb listing data to understand market trends, pricing patterns, customer preferences, and host performance. By examining factors such as neighborhood, room type, availability, reviews, and pricing, the analysis aims to identify opportunities for improving occupancy rates, optimizing pricing strategies, and enhancing the overall guest experience. The insights generated will help Airbnb hosts make informed business decisions and enable travelers to choose accommodations that best match their budget and preferences.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-47c7f430-e13f-4813-a26d-a6bd052ebf0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47c7f430-e13f-4813-a26d-a6bd052ebf0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv("listings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         id                                              name   host_id  \
# 0  2992450                        Luxury 2 bedroom apartment   4621559
# 1  3820211         Restored Precinct in Center Sq. w/Parking  19648678
# 2  5651579        Large studio apt  by Capital Center & ESP@  29288920
# 3  6623339  Center Sq. Loft in Converted Precinct w/ Parking  19648678
# 4  9501054  Spacious suite with full bath by Capital  Center  29288920
#
#        host_profile_id host_name  neighbourhood_group neighbourhood  latitude  \
# 0  1462661762635155041   Kenneth                  NaN    THIRD WARD  42.65789
# 1  1463087024016718788      Ming                  NaN    SIXTH WARD  42.65222
# 2  1465431505328745177     Gregg                  NaN   SECOND WARD  42.64615
# 3  1463087024016718788      Ming                  NaN    SIXTH WARD  42.65222
# 4  1465431505328745177     Gregg                  NaN   SECOND WARD  42.64734
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 490
# Number of columns: 19

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              490 non-null    int64
#  1   name                            490 non-null    object
#  2   host_id                         490 non-null    int64
#  3   host_profile_id                 490 non-null    int64
#  4   host_name                       490 non-null    object
#  5   neighbourhood_group             0 non-null      float64
#  6   neighbourhood                   490 non-null    object
#  7   latitude                        490 non-null    float64
#  8   longitude                       490 non-null    float64
#  9   room_type                       490 non-null    object
#  10  price                           458 non-null    float64
#  11  minimum_nights                  489 non-null    float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"Number of duplicate values: {df.duplicated().sum()}")
# Out:
# Number of duplicate values: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# id                                  0
# name                                0
# host_id                             0
# host_profile_id                     0
# host_name                           0
# neighbourhood_group               490
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                              32
# minimum_nights                      1
# number_of_reviews                   0
# last_review                        60
# reviews_per_month                  60
# calculated_host_listings_count      0
# availability_365                    0
# number_of_reviews_ltm               0
# license                           490
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 490 Airbnb listings with 19 columns covering property details, host information, pricing, location, availability, and customer reviews. It includes both numerical and categorical data. Some columns, such as Price, Minimum Nights, Last Review, and Reviews Per Month, have missing values, while Neighbourhood Group and License contain only missing values and can be removed during data cleaning. The dataset is suitable for analyzing Airbnb pricing trends, room types, host performance, and customer behavior.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_profile_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include="all")
# Out:
#                   id                                            name  \
# count   4.900000e+02                                             490
# unique           NaN                                             489
# top              NaN  Large Bedroom in the heart of downtown Albany.
# freq             NaN                                               2
# mean    9.617549e+17                                             NaN
# std     5.800837e+17                                             NaN
# min     2.992450e+06                                             NaN
# 25%     6.904915e+17                                             NaN
# 50%     1.112067e+18                                             NaN
# 75%     1.458295e+18                                             NaN
# max     1.701483e+18                                             NaN
#
#              host_id  host_profile_id           host_name  \
# count   4.900000e+02     4.900000e+02                 490
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ***id**:Unique identifier for each Airbnb listing.
# **name**:Name or title of the Airbnb listing.
# **host_id**:Unique identifier of the host.
# **host_profile_id**:Unique profile ID of the host.
# **host_name**:Name of the host.
# **neighbourhood_group**:Group or region of the neighborhood (contains missing values).
# **neighbourhood**:Neighborhood where the property is located
# **latitude**:Latitude coordinate of the property.
# **longitude**:Longitude coordinate of the property.
# **room_type**:Type of accommodation (Entire home, Private room, etc.).
# price	Price per night for the listing.
# **minimum_nights**:Minimum number of nights required to book the property **number_of_reviews**:Total number of reviews received by the listing
# **last_review**:Date of the most recent customer review
# **reviews_per_month**:Average number of reviews received per month.
# **calculated_host_listings_count**:	Total number of listings managed by the host.
# **availability_365**:Number of days the listing is available for booking in a year.
# **number_of_reviews_ltm**:Number of reviews received in the last 12 months.
# license

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 490 .
# No. of unique values in  name is 489 .
# No. of unique values in  host_id is 186 .
# No. of unique values in  host_profile_id is 186 .
# No. of unique values in  host_name is 169 .
# No. of unique values in  neighbourhood_group is 0 .
# No. of unique values in  neighbourhood is 15 .
# No. of unique values in  latitude is 459 .
# No. of unique values in  longitude is 469 .
# No. of unique values in  room_type is 4 .
# No. of unique values in  price is 228 .
# No. of unique values in  minimum_nights is 22 .
# No. of unique values in  number_of_reviews is 150 .
# No. of unique values in  last_review is 196 .
# No. of unique values in  reviews_per_month is 253 .
# No. of unique values in  calculated_host_listings_count is 16 .
# No. of unique values in  availability_365 is 214 .
# No. of unique values in  number_of_reviews_ltm is 67 .
# No. of unique values in  license is 0 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of the original DataFrame
df1 = df.copy()

print("Checking Duplicate value")
print(df1.duplicated().sum())
print()
print("Droping Unnecessary columns")
df1.columns
df1=df1.drop(["neighbourhood_group","minimum_nights","number_of_reviews","last_review","reviews_per_month","calculated_host_listings_count","availability_365","number_of_reviews_ltm","license"],axis=1)
print("Droped Columns")
print(df1.columns)
print()
print("Checking null value")
print(df1.isnull().sum())
df1["price"].fillna(df1["price"].mean(),inplace=True)
print("Null values have removed")
print(df1.isnull().sum())
# Out:
# Checking Duplicate value
# 0
#
# Droping Unnecessary columns
# Droped Columns
# Index(['id', 'name', 'host_id', 'host_profile_id', 'host_name',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price'],
#       dtype='object')
#
# Checking null value
# id                  0
# name                0
# host_id             0
# host_profile_id     0
# host_name           0
# neighbourhood       0
# latitude            0
# longitude           0
# room_type           0
# price              32
# dtype: int64
# Null values have removed
# id                 0
# name               0
# host_id            0
# host_profile_id    0
# host_name          0
# neighbourhood      0
# latitude           0
# longitude          0
# room_type          0
# price              0
# dtype: int64
# /tmp/ipykernel_2337/1192312190.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The dataset was cleaned and prepared for analysis by performing several data preprocessing steps. First, the dataset was checked for duplicate records, and no duplicate values were found. Next, unnecessary columns that were not required for the analysis were removed, reducing the dataset to the most relevant features such as listing ID, property name, host details, neighborhood, location coordinates, room type, and price. The dataset was then examined for missing values, where the price column was found to contain 32 null values. These missing values were handled to ensure the dataset contained no null values before analysis. After completing the cleaning process, the dataset became consistent, accurate, and ready for further exploratory data analysis and visualization.
#
# From the cleaned dataset, it was observed that there were no duplicate listings, indicating good data quality. The only significant missing values were found in the price column, while the remaining selected columns were complete. The cleaned data can now be used to analyze pricing patterns across neighborhoods, compare room types, study host listings, and understand the geographical distribution of Airbnb properties, enabling meaningful business insights and better decision-making.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Price Distribution

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8,5))
sns.histplot(df1['price'], bins=30, kde=True)
plt.title("Distribution of Airbnb Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because it is the most suitable chart for displaying the distribution of a continuous numerical variable such as price. It helps identify the frequency of listings within different price ranges, making it easy to understand the overall pricing pattern, detect skewness, and identify any unusually high or low-priced listings (outliers).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that Airbnb listing prices are positively (right) skewed, meaning that most listings are concentrated in the lower price range, approximately between ₹50 and ₹200. As prices increase, the number of listings decreases significantly. Only a few listings are priced above ₹500, with some luxury properties reaching nearly ₹1,700. This indicates that the majority of Airbnb properties are affordable, while premium listings represent only a small portion of the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact. Since most customers prefer affordable accommodations, hosts can set competitive prices within the popular price range to attract more bookings. The platform can also promote budget-friendly listings to increase occupancy rates and customer satisfaction. Additionally, luxury listings can be marketed separately to target premium travelers.
#
# A potential negative insight is that high-priced listings have lower representation, which may indicate lower demand or a limited customer base for expensive properties. If hosts consistently set prices much higher than the market average without offering additional value or amenities, they may experience fewer bookings, reducing occupancy rates and overall revenue. Therefore, pricing strategies should align with customer demand and market trends to maximize business performance.

# %% [markdown]
# #### Chart - 2 Listing By Neighbourhood

# %%
# Chart - 2 visualization code
plt.figure(figsize=(12,6))
sns.countplot(data=df1,
              y='neighbourhood',
              order=df['neighbourhood'].value_counts().head(10).index)

plt.title("Top 10 Neighborhoods by Number of Listings")
plt.xlabel("Number of Listings")
plt.ylabel("Neighborhood")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is the most effective way to compare the number of Airbnb listings across different neighborhoods. It clearly displays the ranking of neighborhoods from highest to lowest and makes it easy to compare categories with long names without cluttering the chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that SIXTH WARD has the highest number of Airbnb listings, with approximately 117 listings, making it the most active neighborhood in the dataset. TENTH WARD ranks second with around 56 listings, while THIRD WARD, NINTH WARD, SECOND WARD, and THIRTEENTH WARD have a moderate number of listings, ranging from approximately 41 to 43. FOURTH WARD and FIFTEENTH WARD have the fewest listings among the top ten, indicating a lower Airbnb presence in those areas. Overall, the distribution of listings is uneven, with a few neighborhoods dominating the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact. Identifying neighborhoods with the highest number of listings helps Airbnb and property owners understand where market demand and supply are concentrated. Hosts can choose high-demand neighborhoods for investment, while the platform can focus promotional campaigns on emerging areas to attract more guests. Additionally, neighborhoods with fewer listings may present opportunities for new hosts to enter the market with less competition.
#
# A potential negative insight is that the heavy concentration of listings in SIXTH WARD may lead to increased competition among hosts. This could result in price reductions, lower occupancy rates, and reduced profitability if the supply of listings grows faster than customer demand. Diversifying listings across other neighborhoods could help balance the market and improve overall business performance.

# %% [markdown]
# #### Chart - 3 Average Price By RoomType

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8,5))
sns.barplot(data=df1,
            x='room_type',
            y='price',
            estimator='mean')

plt.title("Average Price by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it is the most suitable visualization for comparing the average prices of different room types. It allows for an easy comparison of categorical data and clearly highlights which room type has the highest and lowest average price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a significant difference in average prices across room types. Shared rooms have the highest average price, approximately ₹840, making them the most expensive category in the dataset. Hotel rooms have the second-highest average price at around ₹220, followed closely by Entire home/apartment at approximately ₹210. Private rooms are the most affordable option, with an average price of about ₹90. The exceptionally high average price for shared rooms may indicate the presence of a few expensive listings that increase the overall average.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact. Understanding the average price of each room type enables hosts to set competitive prices and helps customers choose accommodations that match their budget. It also allows Airbnb to recommend suitable room types based on customer preferences and spending capacity.
#
# A potential negative insight is that the unusually high average price of shared rooms is not consistent with typical market trends, where shared rooms are generally the least expensive option. This suggests that a few high-priced listings or outliers may be influencing the average. If hosts set prices based only on this average without considering the market, it could reduce bookings and customer satisfaction. Therefore, further analysis, such as examining the median price or identifying outliers, is recommended before making pricing decisions.

# %% [markdown]
# #### Chart - 4 Price by Room Type

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8,5))
sns.boxplot(data=df1,
            x='room_type',
            y='price')

plt.title("Price Distribution by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen because it is the best visualization for comparing the distribution of prices across different room types. It displays the median, interquartile range (IQR), overall spread of the data, and any outliers. This makes it easy to identify price variation and detect unusually expensive listings within each room category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows that Private rooms have the lowest median price and the smallest price variation, indicating they are the most affordable and consistently priced option. Entire homes/apartments and Hotel rooms have higher median prices and a wider spread, suggesting greater variation in pricing. The Entire home/apartment category contains many high-priced outliers, with some listings exceeding ₹1,700, indicating the presence of luxury properties. Shared rooms appear to have almost no variation because there are very few observations in this category, resulting in a single or nearly identical price point.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can positively impact business decisions by helping hosts understand the pricing patterns for different room types and set competitive prices. Customers can also make informed choices based on their budgets, while Airbnb can recommend listings that match guest preferences. The identification of outliers allows hosts and the platform to review whether premium prices are justified by the property's features and location.
#
# A potential negative insight is the presence of numerous high-priced outliers in the Entire home/apartment category. If these properties are priced significantly above market expectations without offering additional value, they may receive fewer bookings, leading to lower occupancy and reduced revenue. Additionally, the limited data for Shared rooms makes it difficult to draw reliable conclusions about their pricing, suggesting that more data should be collected before making business decisions for this room type.

# %% [markdown]
# #### Chart - 5 Reviews Vs Price

# %%
# Chart - 5 visualization code
df2=df.copy()
plt.figure(figsize=(8,5))
sns.scatterplot(data=df2,
                x='number_of_reviews',
                y='price')

plt.title("Number of Reviews vs Price")
plt.xlabel("Number of Reviews")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it is the most appropriate chart for analyzing the relationship between two numerical variables: number of reviews and price. It helps identify trends, correlations, clusters, and outliers, making it easier to understand whether the number of customer reviews has any influence on Airbnb listing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows that there is no strong correlation between the number of reviews and the price of Airbnb listings. Most listings are priced below ₹300, regardless of the number of reviews they have received. Listings with a high number of reviews (more than 400) are generally moderately priced rather than expensive. A few listings have very high prices (above ₹800), but these listings have relatively few reviews, suggesting that premium-priced properties are less frequently reviewed. Overall, the chart indicates that customer reviews alone do not determine the price of a listing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can have a positive business impact. Hosts can understand that increasing the number of reviews does not necessarily require increasing prices. Instead, maintaining reasonable pricing while providing quality service can encourage more bookings and customer reviews. Airbnb can also use this information to recommend competitively priced listings with high review counts, increasing customer trust and satisfaction.
#
# A potential negative insight is that high-priced listings tend to receive fewer reviews, which may indicate lower booking frequency due to their premium pricing. If hosts set prices significantly above market expectations, their properties may attract fewer guests, resulting in fewer reviews, lower occupancy rates, and reduced revenue. Therefore, balancing pricing with customer demand is important for long-term business growth.

# %% [markdown]
# #### Chart - 6 Availability Vs Price

# %%
# Chart - 6 visualization code
plt.figure(figsize=(8,5))
sns.scatterplot(data=df2,
                x='availability_365',
                y='price')

plt.title("Availability vs Price")
plt.xlabel("Availability (Days)")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it is the most suitable visualization for examining the relationship between two numerical variables: availability (number of days available) and price. It helps identify patterns, trends, clusters, and outliers, making it easier to determine whether the availability of a listing has any effect on its pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot indicates that there is no strong correlation between the availability of a listing and its price. Most Airbnb listings are priced below ₹300, regardless of how many days they are available during the year. A large number of listings are available for more than 300 days, suggesting that many properties remain available for booking throughout the year. A few listings with very high prices (above ₹800) are scattered across different availability levels, showing that premium-priced properties are not associated with a specific availability pattern. Overall, availability alone does not appear to significantly influence the price of Airbnb listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact. Hosts can understand that keeping a property available for more days does not automatically justify charging higher prices. Instead, pricing should be based on factors such as location, room type, amenities, and customer demand. Airbnb can also use this information to recommend competitively priced listings with higher availability, improving booking opportunities and customer satisfaction.
#
# A potential negative insight is that many listings remain available for most of the year, particularly those with over 300 available days. This may indicate lower booking rates or reduced demand for some properties. If hosts do not adjust their pricing or improve their listing quality, these properties may continue to experience low occupancy, leading to reduced revenue and slower business growth.

# %% [markdown]
# #### Chart - 7 Top 10 Expensive Neighbourhoods

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12,6))

avg_price = df1.groupby('neighbourhood')['price'].mean().sort_values(ascending=False).head(10)

sns.barplot(x=avg_price.values,
            y=avg_price.index)

plt.title("Top 10 Neighborhoods by Average Price")
plt.xlabel("Average Price")
plt.ylabel("Neighborhood")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is the most appropriate visualization for comparing the average prices of different neighborhoods. It clearly ranks neighborhoods from the highest to the lowest average price, making it easy to identify premium and budget-friendly locations. The horizontal layout also improves readability when neighborhood names are long.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that FIFTEENTH WARD has the highest average Airbnb price, at approximately ₹345, making it the most expensive neighborhood in the dataset. EIGHTH WARD and SEVENTH WARD follow with average prices of around ₹250 and ₹235, respectively. On the other hand, SIXTH WARD has the lowest average price among the top ten neighborhoods, at approximately ₹165. The variation in average prices across neighborhoods indicates that location plays a significant role in determining Airbnb pricing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact. Hosts can use neighborhood pricing trends to set competitive rates, while guests can choose accommodations that fit their budget. Airbnb can also use this information to recommend properties based on location and pricing preferences, improving customer satisfaction and booking rates. Additionally, investors can identify high-value neighborhoods for future property investments.
#
# A potential negative insight is that neighborhoods with very high average prices, such as FIFTEENTH WARD, may attract fewer budget-conscious travelers, which could reduce booking rates if prices are not supported by quality, amenities, or location advantages. Similarly, lower-priced neighborhoods may generate less revenue per booking, requiring hosts to achieve higher occupancy rates to maintain profitability. Therefore, pricing should be balanced with market demand and customer expectations.

# %% [markdown]
# #### Chart - 8 Reviews Distribution by Room Type

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8,5))

sns.boxplot(data=df2,
            x='room_type',
            y='number_of_reviews')

plt.title("Reviews by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Number of Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen because it is an effective visualization for comparing the distribution of the number of reviews across different room types. It displays the median, interquartile range (IQR), overall spread, and outliers, making it easy to identify which room types receive more reviews and how review counts vary among them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Entire home/apartment listings receive the highest number of reviews and have the greatest variation in review counts. Several listings in this category have exceptionally high reviews, with some reaching nearly 1,000 reviews, indicating high customer demand and popularity. Private rooms also receive a considerable number of reviews but generally fewer than entire homes. Shared rooms and Hotel rooms have very few reviews and minimal variation, suggesting that these room types are less frequently booked or are less common in the dataset. Overall, entire homes appear to be the most popular accommodation type among guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact. Since Entire home/apartment listings consistently receive more reviews, Airbnb and hosts can focus on improving and promoting these properties to attract more bookings. Hosts of private rooms can also enhance amenities and guest experiences to increase customer engagement and reviews.
#
# A potential negative insight is that Shared rooms and Hotel rooms receive very few reviews, which may indicate lower demand or fewer available listings. If these room types continue to receive limited customer attention, hosts may experience lower occupancy rates and reduced revenue. Improving pricing strategies, property features, or marketing efforts could help increase their visibility and booking performance.

# %% [markdown]
# #### Chart - 9 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,7))

corr = df2[['price',
           'minimum_nights',
           'number_of_reviews',
           'reviews_per_month',
           'availability_365',
           'number_of_reviews_ltm',
           'calculated_host_listings_count']].corr()

sns.heatmap(corr,
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap was chosen because it is the most effective visualization for showing the correlation between multiple numerical variables in a single chart. It helps identify the strength and direction of relationships using color intensity and correlation coefficients, making it easier to understand which variables are strongly related and which have little or no relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows that reviews_per_month and number_of_reviews_ltm have the strongest positive correlation (0.87), indicating that listings receiving more monthly reviews also tend to receive more reviews in the last 12 months. There is also a strong positive correlation (0.68) between number_of_reviews and reviews_per_month, suggesting that popular listings continue to attract reviews over time. On the other hand, price has very weak correlations with most variables, indicating that pricing is not strongly influenced by factors such as availability, number of reviews, or host listing count. Additionally, minimum_nights has a moderate negative correlation (-0.29) with reviews_per_month, implying that listings requiring longer minimum stays tend to receive fewer monthly reviews.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The analysis of the Airbnb dataset provides valuable insights that can help hosts, guests, and the Airbnb platform make better decisions. By examining pricing patterns, room types, neighborhood performance, availability, and customer reviews, hosts can set competitive prices based on market trends and property characteristics. The analysis also identifies high-demand neighborhoods and popular room types, enabling hosts and investors to focus on locations with greater booking potential. Understanding customer review patterns helps improve service quality and guest satisfaction, while availability analysis supports better occupancy management. Overall, these insights enable Airbnb and property owners to optimize pricing strategies, improve listing performance, increase booking rates, and enhance the overall customer experience, ultimately contributing to higher revenue and sustainable business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The exploratory data analysis of the Airbnb dataset provided valuable insights into pricing, room types, neighborhood performance, availability, and customer reviews. The analysis revealed that most listings are concentrated in the lower price range, making Airbnb largely affordable for travelers. Entire homes/apartments were found to be the most popular accommodation type, receiving the highest number of reviews, while private rooms remained the most budget-friendly option. Neighborhood analysis highlighted differences in both listing availability and average prices, showing that location plays a significant role in determining property value. The correlation analysis indicated that review-related variables are strongly associated with each other, whereas price has only a weak relationship with most numerical features. Overall, the project demonstrates that data-driven insights can help hosts optimize pricing, improve occupancy rates, enhance guest satisfaction, and support better business decisions, leading to increased revenue and sustainable growth for the Airbnb platform.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
