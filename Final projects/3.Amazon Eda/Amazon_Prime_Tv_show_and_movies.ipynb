# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows & Movies – EDA Assignment

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project performs an Exploratory Data Analysis (EDA) on the Amazon Movies and TV Shows dataset to understand the content available on Amazon Prime Video. The dataset includes details such as movie and TV show titles, release year, genres, runtime, age certification, production countries, IMDb ratings, IMDb votes, TMDb popularity, and TMDb scores.
#
# The project starts by cleaning the data, handling missing values, removing duplicates, and preparing the dataset for analysis. After preprocessing, different charts and visualizations are created to explore trends such as the number of movies versus TV shows, content released over the years, popular genres, top production countries, runtime distribution, and highly rated content.
#
# The analysis also compares IMDb ratings, TMDb popularity, and audience votes to understand what makes content popular among viewers. These insights help identify audience preferences, content trends, and the overall growth of Amazon Prime Video's library.
#
# Overall, this project demonstrates how data analysis and visualization can turn raw streaming data into meaningful insights. The findings can help businesses understand customer preferences, improve content recommendations, and support better decisions for future content production and acquisition.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/bhanuprasad121/Final-projects.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid growth of online streaming platforms, Amazon Prime Video offers thousands of movies and TV shows across different genres, countries, and languages. However, understanding audience preferences, content trends, and the factors that influence ratings and popularity can be challenging due to the large volume of data. Without proper analysis, it becomes difficult to identify which content performs well and what drives viewer engagement.
#
# This project aims to perform Exploratory Data Analysis (EDA) on the Amazon Prime Video dataset to uncover meaningful insights into content distribution, release trends, genres, ratings, popularity, and production countries. The findings can help understand user preferences and support better content planning, recommendation systems, and business decisions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to analyze the Amazon Prime Video dataset to understand content trends, audience preferences, and the factors that contribute to the popularity and success of movies and TV shows. By exploring attributes such as genres, release years, ratings, runtime, production countries, and popularity scores, the project aims to identify valuable insights that can support better content recommendations, content acquisition strategies, and business decision-making. These insights can help streaming platforms improve user engagement, optimize their content library, and enhance the overall viewing experience for customers.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-23083bad-e4e0-4d0b-a590-9e91b6435d2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23083bad-e4e0-4d0b-a590-9e91b6435d2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df1 = pd.read_csv("titles.csv")
df2 = pd.read_csv("credits.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
display(df1.head())
display(df2.head())
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows of Title dataset:",df1.shape[0])
print("Number of Columns of Title dataset:",df1.shape[1])
print("Number of Rows of Credit dataset:",df2.shape[0])
print("Number of Columns of Credit dataset:",df2.shape[1])
# Out:
# Number of Rows of Title dataset: 9871
# Number of Columns of Title dataset: 15
# Number of Rows of Credit dataset: 124235
# Number of Columns of Credit dataset: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Title Dataset Information")
display(df1.info())
print("\n")
print("Credit Dataset Information")
display(df2.info())
# Out:
# Title Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print("Duplicate Values in Title Dataset:",df1.duplicated().sum())
print("Duplicate Values in Credit Dataset:",df2.duplicated().sum())
# Out:
# Duplicate Values in Title Dataset: 3
# Duplicate Values in Credit Dataset: 56

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("Missing Values in Title Dataset")
display(df1.isnull().sum())
print("\n")
print("Missing Values in Credit Dataset")
display(df2.isnull().sum())
# Out:
# Missing Values in Title Dataset
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64
# Missing Values in Credit Dataset
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
plt.title("Missing Values in Title Dataset")
sns.heatmap(df1.isnull(), cbar=False)
plt.show()

# %%
plt.title("Missing Values in Credit Dataset")
sns.heatmap(df2.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Credits dataset contains information about the cast and crew involved in movies and TV shows available on Amazon Prime Video. Each row represents a person associated with a specific title, either as an actor or another contributor. This dataset can be linked with the Titles dataset using the common id column to perform detailed analysis of movies, TV shows, actors, and directors.
#
# The Titles dataset contains detailed information about movies and TV shows available on Amazon Prime Video. Each row represents a unique title and includes information such as its name, type, release year, runtime, genres, production country, audience ratings, and popularity. This dataset helps analyze content trends, viewer preferences, and overall platform performance.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Columns of Title Dataset")
display(df1.columns)
print("\n")
print("Columns of Credit Dataset")
display(df2.columns)
# Out:
# Columns of Title Dataset
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
# Columns of Credit Dataset
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
display(df1.describe(include="all"))
display(df2.describe(include="all"))
# Out:
#              id           title   type         description  release_year  \
# count      9871            9871   9871                9752   9871.000000
# unique     9868            9737      2                9734           NaN
# top     tm89134  The Lost World  MOVIE  No overview found.           NaN
# freq          2               3   8514                   5           NaN
# mean        NaN             NaN    NaN                 NaN   2001.327221
# std         NaN             NaN    NaN                 NaN     25.810071
# min         NaN             NaN    NaN                 NaN   1912.000000
# 25%         NaN             NaN    NaN                 NaN   1995.500000
# 50%         NaN             NaN    NaN                 NaN   2014.000000
# 75%         NaN             NaN    NaN                 NaN   2018.000000
# max         NaN             NaN    NaN                 NaN   2022.000000
#
#        age_certification      runtime     genres production_countries  \
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **The variables of Title Dataset**
# **id**: Unique identifier for each movie or TV show. Used to connect with the Credits dataset.
# **title**:Name of the movie or TV show.
# **type**:Indicates whether the content is a Movie or TV Show.
# **description**:Brief summary of the content.
# **release_year**:Year in which the movie or TV show was released.
# **age_certification**:Age rating of the content (e.g., PG, TV-14, R, TV-MA).
# **runtime**:Duration of the movie or episode in minutes.
# **genres**:Genre(s) of the content (e.g., Drama, Comedy, Action).
# **production_countries**:Country or countries where the content was produced.
# **seasons**:Number of seasons (applicable only to TV Shows).
# **imdb_id**Unique IMDb identifier for the title.
# **imdb_score**:IMDb rating given by viewers.
# **imdb_votes**:Total number of votes received on IMDb.
# **tmdb_popularity**:Popularity score from The Movie Database (TMDb).
# **tmdb_score**:Average user rating on TMDb.
#
# **The Variables of Credit Dataset**
# **person_id**:Unique identifier assigned to each person in the dataset.
# **id**:Unique identifier of the movie or TV show. This column is used to link the Credits dataset with the Titles dataset.
# **name**:Name of the actor or crew member associated with the title.
# **character**:Name of the character played by the actor. This field is mainly applicable to actors and may be empty for crew members.
# **role**:	Specifies the person's role in the title, such as ACTOR, DIRECTOR, or other production roles.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df1.columns:
  print(f"Unique Values in {col}:")
  print(df1[col].unique())
  print("\n")
for col in df2.columns:
  print(f"Unique Values in {col}:")
  print(df2[col].unique())
  print("\n")
# Out:
# Unique Values in id:
# ['ts20945' 'tm19248' 'tm82253' ... 'tm847725' 'tm1054116' 'ts275838']
#
#
# Unique Values in title:
# ['The Three Stooges' 'The General' 'The Best Years of Our Lives' ...
#  'Chasing' 'Baikunth' 'Waking Up Eighty']
#
#
# Unique Values in type:
# ['SHOW' 'MOVIE']
#
#
# Unique Values in description:
# ["The Three Stooges were an American vaudeville and comedy team active from 1922 until 1970, best known for their 190 short subject films by Columbia Pictures that have been regularly airing on television since 1958. Their hallmark was physical farce and slapstick. In films, the stooges were commonly known by their actual first names. There were a total of six stooges over the act's run (with only three active at any given time), but Moe Howard and Larry Fine were the mainstays throughout the ensemble's nearly fifty-year run."
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df1_Copy=df1.copy()
df2_Copy=df2.copy()

# checking missing values
print("Missing Values in Title Dataset")
display(df1_Copy.isnull().sum())
print("\n")
print("Missing Values in Credit Dataset")
display(df2_Copy.isnull().sum())
print()
print(df1_Copy.info())
print()
print(df1_Copy.describe(include="all"))

#Checking Duplicate Values
print("Before Deleting Duplicates")
print("Duplicate Values in Title Dataset:",df1_Copy.duplicated().sum())
print("/n")
print("Duplicate Values in Credit Dataset:",df2_Copy.duplicated().sum())
# Deleting Duplicates
print("After Deleting Duplicates")
df1_Copy.drop_duplicates(inplace=True)
df2_Copy.drop_duplicates(inplace=True)
print("Duplicate Values in Title Dataset:",df1_Copy.duplicated().sum())
print("/n")
print("Duplicate Values in Credit Dataset:",df2_Copy.duplicated().sum())

# Cleaning
df1_Copy["type"]=df1_Copy["type"].str.lower()
df1_Copy["genres"]=df1_Copy["genres"].str.lower()
df1_Copy["production_countries"]=df1_Copy["production_countries"].str.lower()
df1_Copy["genres"]=df1_Copy["genres"].str.replace(r"[\[\]']", "", regex=True)
df1_Copy["production_countries"]=df1_Copy["production_countries"].str.replace(r"[\[\]']", "", regex=True)
# Out:
# Missing Values in Title Dataset
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64
# Missing Values in Credit Dataset
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The Titles and Credits datasets were first copied to preserve the original data. Missing values were checked in both datasets to identify incomplete records, and the dataset structure was examined using info() and describe(). The release_year column was converted to a datetime format to enable time-based analysis. Duplicate records were identified and removed from both datasets to improve data quality and eliminate redundant information. Additionally, the type and genres columns were converted to lowercase to maintain consistency, while the genres and production_countries columns were cleaned by removing brackets and quotes, making them easier to analyze and visualize.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Content Type By Count

# %%
# Chart - 1 Content type
plt.figure(figsize=(6,5))
plt.title("Content Type by Count")
ax=sns.countplot(x="type",data=df1_Copy)
ax.bar_label(ax.containers[0], fmt='%d', padding=3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot (bar chart) was chosen because the variable type is categorical with two categories: Movie and Show. This chart clearly compares the number of titles in each category, making it easy to understand the content distribution on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Amazon Prime Video has approximately 8,511 movies and 1,357 TV shows. This means that movies account for nearly 86% of the content, while TV shows make up only about 14%. The platform clearly focuses more on movies than television series.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The large movie library helps Amazon Prime Video attract users looking for a wide variety of films. However, the relatively small number of TV shows may reduce engagement among users who prefer binge-watching series. Expanding the TV show catalog while maintaining a strong movie collection could increase user retention, viewing time, and overall subscriber satisfaction by catering to a broader audience.

# %% [markdown]
# #### Chart - 2 Distribution of Content Across Release Years

# %%
# Chart - 2 Distribution of Content Across Release Years
release_count = (
    df1_Copy["release_year"]
    .value_counts()
    .sort_index()
)
plt.figure(figsize=(20,6))
ax = sns.barplot(
    x=release_count.index,
    y=release_count.values,
    color="steelblue"
)
ax.bar_label(ax.containers[0], fontsize=8)
plt.title("Distribution of Content Across Release Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly shows the number of movies and TV shows released each year, making it easy to compare content production over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Amazon Prime's library contains content released from 1912 to 2022.
# Very few titles were released before the 1980s.
# Content production started increasing steadily after 2000.
# The highest number of releases occurred between 2018 and 2021, with 2021 having approximately 856 titles, making it the peak year.
# There is a noticeable decline in 2022, likely because the dataset contains only part of that year's releases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The sharp increase in recent years indicates that Amazon Prime has significantly expanded its content library to meet growing demand and compete with other streaming platforms. Maintaining a steady release schedule of new content can improve subscriber engagement and retention, while the lower number of older titles highlights an opportunity to expand classic content for viewers interested in vintage films and TV shows.

# %% [markdown]
# #### Chart - 3 Genre  Distribution

# %%
# Chart - 3 Genre Distribution
genre_counts = df1_Copy["genres"].value_counts().head(10)
plt.figure(figsize=(10,6))
ax = sns.barplot(
    x=genre_counts.index,
    y=genre_counts.values,
    color="steelblue"
)
ax.bar_label(ax.containers[0], fontsize=8)
plt.title("Genre Distribution")
plt.xlabel("Genre")
plt.ylabel("Number of Titles")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because genres are categorical variables. It provides a clear comparison of the number of titles available in each genre and helps identify the most and least common genres on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Drama is the most common genre with 908 titles, making it the dominant content category.
# Comedy is the second most popular genre with 686 titles.
# Documentation/Documentary ranks third with 493 titles, showing a significant presence of factual content.
# Genres such as Horror (217), Thriller (189), and Drama-Romance (181) have moderate representation.
# Combined genres like Comedy-Drama (153) and Drama-Comedy (151) have fewer titles, while Thriller-Drama (120) is the least represented among the top 10 genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The dominance of Drama and Comedy indicates that these genres are highly valued by viewers and should continue to be a priority for content acquisition and production. The strong presence of documentaries suggests growing audience interest in educational and real-life content. However, the relatively lower number of titles in genres such as Thriller and Horror presents an opportunity for Amazon Prime Video to expand its content library in these categories, attracting a wider audience and improving overall viewer engagement.

# %% [markdown]
# #### Chart - 4 Genre By Type

# %%
# Chart - 4 Genre By Type
genre_type=df1_Copy.copy()
genre_type["genres"]=genre_type["genres"].str.split(",")
genre_type=genre_type.explode("genres")
genre_type["genres"] = genre_type["genres"].str.strip()
genre_type=genre_type.groupby(["type","genres"]).size().reset_index(name="count")

top_genres=genre_type.groupby("genres")["count"].sum().sort_values(ascending=False).head(10).index
genre_type = genre_type[
    genre_type["genres"].isin(top_genres)
]
plt.figure(figsize=(10,6))
ax=sns.barplot(data=genre_type,x="genres",y="count",hue="type")
for containers in ax.containers:
  ax.bar_label(ax.containers[0], fontsize=8)
plt.title("Top Genres by Type")
plt.xlabel("Genre")
plt.ylabel("Number of Titles")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart was chosen because it effectively compares the number of Movies and TV Shows across different genres. It helps identify which genres are more dominant in each content type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Drama is the most dominant genre on Amazon Prime Video, with 4,224 movies and approximately 540 TV shows.
# Comedy is the second most popular genre, containing 2,556 movies and around 420 TV shows.
# Thriller (1,985 movies), Romance (1,620 movies), and Action (1,631 movies) are also highly represented in the movie category.
# TV shows are much fewer than movies across all genres, with Drama and Comedy having the highest number of TV shows.
# Genres such as European (596 movies) and Family (529 movies) have comparatively fewer titles than the leading genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The analysis shows that Drama and Comedy are the strongest-performing genres for both Movies and TV Shows, suggesting they are popular among viewers. Amazon Prime Video should continue investing in these genres to maintain audience engagement. At the same time, genres such as Family, European, and Crime have relatively fewer titles, providing an opportunity to expand the content library and attract niche audiences. Since movies significantly outnumber TV shows in every genre, increasing the production or acquisition of TV series in popular genres like Drama, Comedy, and Action could improve subscriber retention and encourage longer viewing sessions through binge-watching.

# %% [markdown]
# #### Chart - 5  Country-wise Analysis

# %%
country_df = df1_Copy.copy()
import ast
def clean_country(value):

    if isinstance(value, list):
        return value

    if pd.isna(value):
        return []

    value = str(value).strip()

    try:
        result = ast.literal_eval(value)
        if isinstance(result, list):
            return result
    except (ValueError, SyntaxError):
        pass

    return [item.strip() for item in value.split(",") if item.strip()]

country_df["production_countries"] = (
    country_df["production_countries"].apply(clean_country)
)

country_df = country_df.explode("production_countries")

country_df["production_countries"] = (
    country_df["production_countries"].astype(str).str.strip()
)

country_df = country_df[
    country_df["production_countries"].notna()
    & ~country_df["production_countries"].isin(["", "[]", "nan", "None"])
]

country_count = (
    country_df["production_countries"]
    .value_counts()
    .head(10)
)

print(country_count)

plt.figure(figsize=(10, 6))

ax = sns.barplot(
    x=country_count.values,
    y=country_count.index
)

if ax.containers:
    ax.bar_label(ax.containers[0], padding=3)

plt.title("Top 10 Production Countries")
plt.xlabel("Number of Titles")
plt.ylabel("Production Country")
plt.tight_layout()
plt.show()
# Out:
# production_countries
# us    5331
# in    1072
# gb     928
# ca     530
# fr     250
# jp     197
# au     173
# de     172
# cn     143
# it     143
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it clearly compares the number of titles produced by different countries. It is ideal for ranking countries from highest to lowest production and is easier to read than a vertical bar chart when country names are displayed on the y-axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The United States (US) is the largest content producer on Amazon Prime Video with 5,331 titles, contributing significantly more content than any other country.
# India (IN) ranks second with 1,072 titles, followed by the United Kingdom (GB) with 928 titles.
# Canada (530) and France (250) also contribute a notable number of titles, but far less than the top three countries.
# Countries such as Japan (197), Australia (173), Germany (172), China (143), and Italy (143) have comparatively smaller content libraries.
# The large difference between the United States and other countries shows that Amazon Prime Video's catalog is heavily dominated by US-produced content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The strong dominance of US-produced content suggests that Amazon Prime Video relies heavily on the American entertainment industry to build its content library. While this helps attract audiences interested in Hollywood productions, expanding investments in countries such as India, Japan, Germany, and other emerging markets could diversify the platform's catalog and appeal to a broader global audience. Increasing regional and multilingual content can improve subscriber growth, enhance user engagement, and strengthen Amazon Prime Video's presence in international markets.

# %% [markdown]
# #### Chart - 6 Year Vs Genres

# %%
# Chart - 6 visualization code
heatmap_df = df1_Copy.copy()

heatmap_df["genres"] = heatmap_df["genres"].str.split(",")

heatmap_df = heatmap_df.explode("genres")

heatmap_df["genres"] = heatmap_df["genres"].str.strip()

top_genres = heatmap_df["genres"].value_counts().head(10).index
heatmap_df = heatmap_df[heatmap_df["genres"].isin(top_genres)]

pivot = pd.pivot_table(
    heatmap_df,
    values="id",
    index="genres",
    columns="release_year",
    aggfunc="count",
    fill_value=0
)

plt.figure(figsize=(16,6))

sns.heatmap(
    pivot,
    cmap="viridis",
    linewidths=0.5,
    linecolor="white"
)

plt.title("Year Vs Genres")
plt.xlabel("Release Year")
plt.ylabel("Genre")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap was chosen because it effectively displays the relationship between genres and release years. The color intensity makes it easy to identify years and genres with high or low numbers of releases, allowing trends to be spotted quickly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Drama is the most dominant genre across almost all years, with a sharp increase after 2015 and reaching its highest number of releases between 2018 and 2021.
# Comedy is the second most popular genre and also shows steady growth in recent years.
# Thriller, Action, and Romance experienced noticeable growth after 2010, indicating increasing investment in these genres.
# Documentation, Crime, Family, and European genres have relatively fewer releases compared to Drama and Comedy.
# Before the 1990s, the number of releases across all genres was relatively low. Content production increased significantly after 2000, especially during the last decade.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The heatmap indicates that Drama and Comedy have consistently been the strongest-performing genres, making them important areas for continued investment. The rapid increase in releases after 2015 reflects Amazon Prime Video's expansion of its content library to meet growing streaming demand. Genres such as Crime, Family, and European have lower production levels, presenting opportunities to diversify the content catalog and attract new audience segments. By analyzing these trends, Amazon Prime Video can make data-driven decisions on future content acquisition and production strategies to improve viewer engagement and subscriber growth.

# %% [markdown]
# #### Chart - 7 Content Release Over Time

# %%
# Chart - 7 Content Release Over Time
line_df = df1_Copy.copy()

if pd.api.types.is_datetime64_any_dtype(line_df["release_year"]):
    line_df["release_year"] = line_df["release_year"].dt.year

year_type = (
    line_df.groupby(["release_year", "type"])
    .size()
    .reset_index(name="count")
)
plt.figure(figsize=(14,6))

ax = sns.lineplot(
    data=year_type,
    x="release_year",
    y="count",
    hue="type",
    marker="o",
    linewidth=2.5
)

plt.title("Content Releases Over Time by Content Type", fontsize=15)
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.legend(title="Content Type")
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A time-series line chart was selected because it clearly shows how the number of releases changed over time. Using separate lines for Movies and TV Shows makes it easy to compare their growth patterns across different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies consistently dominate the Amazon Prime Video catalog across almost all years.
# Movie releases remained relatively low before 2000, then increased rapidly after 2010.
# The strongest growth occurred between 2015 and 2021, with movie releases reaching their highest level around 2021.
# TV show releases were much lower than movies, but they also increased steadily after 2000, especially after 2010.
# The sharp fall in 2022 for both Movies and TV Shows likely means the dataset contains only part of that year, so it should not be treated as a full-year decline.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart shows that Amazon Prime Video has strongly expanded its content library in recent years, mainly through movies. However, the continued growth of TV shows suggests increasing demand for episodic and binge-watching content. Amazon can use this trend to balance future investments between movies and series, increase user engagement, and improve subscriber retention.

# %% [markdown]
# #### Chart - Top 10  Most Credited Directors

# %%
# Chart - 8 visualization code
director_df = df2_Copy[df2_Copy["role"] == "DIRECTOR"]

top_directors = (
    director_df["name"]
    .value_counts()
    .head(10)
)

plt.figure(figsize=(10,6))

ax = sns.barplot(
    x=top_directors.values,
    y=top_directors.index,
    color="steelblue"
)

ax.bar_label(ax.containers[0], padding=3)

plt.title("Top 10 Most Credited Directors")
plt.xlabel("Number of Movies")
plt.ylabel("Director")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it effectively ranks directors based on the number of titles they have directed. It makes it easy to compare the top contributors and identify the most frequently credited directors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Joseph Kane is the most credited director with 41 movies, making him the leading contributor in the dataset.
# Sam Newfield ranks second with 38 titles, followed by Jay Chapman with 34 movies.
# Lesley Selander (22), John English (21), and Harry L. Fraser (21) also have a significant number of directing credits.
# The remaining directors, including William Nigh (20), Manny Rodriguez (17), Robert N. Bradbury (17), and George Archainbaud (16), have consistently contributed multiple titles.
# The noticeable difference between the top three directors and the rest indicates that a small group of directors has produced a large portion of the available content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The analysis identifies the directors who have contributed the most titles to Amazon Prime Video's content library. Understanding these frequent collaborators can help Amazon recognize experienced creators, strengthen partnerships with successful directors, and make informed decisions when acquiring or producing future content. Collaborating with established directors may improve content quality, attract larger audiences, and increase viewer engagement on the platform.

# %% [markdown]
# #### Chart - 9 Top 10 Credited Actors

# %%
# Chart - 9 visualization code
actor_df = df2_Copy[df2_Copy["role"] == "ACTOR"]

top_actors = (
    actor_df["name"]
    .value_counts()
    .head(10)
)

plt.figure(figsize=(10,6))

ax = sns.barplot(
    x=top_actors.values,
    y=top_actors.index,
    color="steelblue"
)

ax.bar_label(ax.containers[0], padding=3)

plt.title("Top 10 Most Credited Actors")
plt.xlabel("Number of Movies")
plt.ylabel("Actors")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it effectively ranks actors based on the number of titles they have appeared in. It makes it easy to compare the top actors and identify those with the highest number of acting credits.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# George 'Gabby' Hayes is the most frequently credited actor with 49 movie appearances, making him the top contributor in the dataset.
# Roy Rogers ranks second with 45 movies, followed closely by Bess Flowers with 44 movies.
# Gene Autry has 40 movie appearances, while Nassar appears in 37 titles.
# Herman Hack and Charles King each have 35 movie appearances, demonstrating consistent involvement in film productions.
# George Morrell, Earl Dwire, and Forrest Taylor each appear in 34 movies, completing the top 10 list.
# The relatively small difference in appearances among the top actors suggests that several performers have made long-term and consistent contributions to the content library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Identifying the most frequently appearing actors helps Amazon Prime Video understand which performers have significantly contributed to its content catalog. These actors often have strong audience recognition and can be valuable for content promotion, recommendation systems, and curated collections. Insights like these can also support licensing decisions, highlight classic cinema collections, and improve viewer engagement by showcasing films featuring popular and frequently credited actors.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(8,6))

sns.violinplot(
    data=df1_Copy,
    x="type",
    y="runtime",
    palette="Set2"
)

plt.title("Runtime Distribution by Content Type")
plt.xlabel("Content Type")
plt.ylabel("Runtime (Minutes)")

plt.show()
# Out:
# /tmp/ipykernel_1927/4257674914.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot was chosen because it displays the distribution, median, and density of runtime for both Movies and TV Shows. It also helps identify the spread of runtimes and highlights unusually short or long durations (outliers).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies have significantly longer runtimes than TV Shows, with most movies concentrated between 80 and 100 minutes.
# TV Shows generally have shorter runtimes, with the majority falling between 20 and 50 minutes, which is typical for episodic content.
# The movie category has a much wider distribution, indicating greater variation in runtime compared to TV Shows.
# A few movies extend beyond 150 minutes, with one extreme outlier reaching over 500 minutes, which is likely a compilation, special edition, or data anomaly.
# TV Shows also contain a few longer-duration outliers, but they are much less extreme than those observed in movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The runtime analysis shows that Amazon Prime Video's movie library mainly consists of standard-length films, while TV Shows are optimized for shorter episodic viewing. This aligns with viewer preferences for binge-watching and flexible viewing sessions. The presence of a few extremely long titles suggests that Amazon should review these entries for data quality or classify them separately if they represent special editions or multi-part collections. Understanding runtime patterns can help improve content recommendations, user engagement, and content acquisition strategies by maintaining a balanced mix of short, medium, and long-form entertainment.

# %%
from sklearn.preprocessing import LabelEncoder

corr_df = df1_Copy.copy()

corr_df = corr_df[[
    "type",
    "release_year",
    "age_certification",
    "runtime",
    "imdb_score",
    "imdb_votes",
    "tmdb_popularity",
    "tmdb_score"
]]
le = LabelEncoder()

for col in corr_df.select_dtypes(include="object").columns:
    corr_df[col] = le.fit_transform(corr_df[col].astype(str))
corr_matrix = corr_df.corr(numeric_only=True)

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    square=True
)

plt.title("Correlation Heatmap of Amazon Prime Dataset")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen because it visually represents the strength and direction of relationships between numerical and encoded categorical variables. It helps identify which features are closely related and which have little or no relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb Score and TMDb Score show the strongest positive correlation (0.58), indicating that titles with higher IMDb ratings also tend to receive higher TMDb ratings.
# IMDb Votes and TMDb Popularity have a moderate positive correlation (0.26), suggesting that popular titles generally receive more user votes.
# Type and Runtime have a strong negative correlation (-0.60). This reflects the difference between Movies and TV Shows, where movies typically have much longer runtimes than TV show episodes.
# Type and IMDb Score (0.33), as well as Type and TMDb Score (0.33), show a weak positive relationship, indicating slight differences in ratings between Movies and TV Shows.
# Release Year has very weak correlations with the other variables, suggesting that the release year alone has little influence on ratings, popularity, or runtime.
# Age Certification also shows weak relationships with most variables, indicating that content ratings (e.g., PG, R, TV-MA) do not strongly affect popularity or review scores.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
pair_df = df1_Copy[[
    "type",
    "runtime",
    "imdb_score",
    "imdb_votes",
    "tmdb_popularity",
    "tmdb_score"
]].dropna()

sns.pairplot(
    pair_df,
    hue="type",
    diag_kind="hist",
    corner=True,
    plot_kws={"alpha": 0.6, "s": 25}
)

plt.suptitle("Pair Plot by Content Type", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it allows multiple variables to be compared simultaneously. It helps identify correlations, distributions, clusters, and outliers between numerical features while also showing differences between Movies and TV Shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb Score and TMDb Score show a clear positive relationship, meaning titles with higher IMDb ratings generally receive higher TMDb ratings as well.
# Movies have a much wider runtime distribution than TV Shows. Most movies range between 80–120 minutes, while TV Shows have much shorter runtimes.
# IMDb Votes are heavily concentrated near lower values, but a few titles receive extremely high numbers of votes, indicating blockbuster or highly popular content.
# TMDb Popularity also contains a few extreme outliers, suggesting that only a small number of titles achieve very high popularity.
# The scatter plots show no strong relationship between runtime and ratings, indicating that longer content does not necessarily receive better reviews.
# The histograms on the diagonal reveal that most titles have IMDb scores between 5 and 8 and TMDb scores between 5 and 7.
# Movies and TV Shows overlap in rating distributions, although Movies occupy a broader range of runtimes.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The analysis provides valuable insights into Amazon Prime Video's content library by identifying trends in content type, genres, production countries, release years, ratings, runtime, and key contributors such as directors and actors. Based on these findings, Amazon Prime Video should continue investing in high-performing genres such as Drama, Comedy, and Action, while expanding content in underrepresented genres to attract a wider audience. Increasing regional content from countries beyond the United States, especially high-growth markets like India and the United Kingdom, can strengthen global reach and subscriber growth. The platform should also focus on collaborating with highly credited directors and actors to produce engaging content. Additionally, using audience ratings (IMDb and TMDb) and popularity metrics to guide content acquisition and recommendation systems can improve viewer satisfaction. By leveraging these data-driven insights, Amazon Prime Video can optimize its content strategy, enhance user engagement, improve content recommendations, and support long-term business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Amazon Prime Video dataset analysis provides valuable insights into the platform's content library and viewing trends. The findings reveal that movies significantly outnumber TV shows, with Drama and Comedy being the most dominant genres. The United States is the leading production country, followed by India and the United Kingdom, indicating a strong concentration of content from these regions. Content production has grown rapidly over the past decade, reflecting the expansion of the streaming industry.
#
# The analysis also shows that IMDb Score and TMDb Score are positively correlated, indicating consistency in audience ratings across platforms. While movies generally have longer runtimes than TV shows, runtime has little impact on content ratings. Additionally, a small number of directors and actors contribute a significant portion of the content library, highlighting key contributors to the platform.
#
# Overall, this EDA demonstrates that Amazon Prime Video can use data-driven insights to improve content acquisition, diversify its catalog, strengthen regional content offerings, and enhance recommendation systems. By focusing on high-performing genres, popular creators, and audience preferences, the platform can improve user engagement, increase subscriber satisfaction, and support long-term business growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
